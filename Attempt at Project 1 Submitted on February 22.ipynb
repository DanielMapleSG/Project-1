# %%
import numpy as np

# %%
import pandas as pd

# %%
import csv

# %%
location = "DC_Properties.csv"

# %%
df= location

# %%
print(df.columns)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-836580d537b0> in <module>
# ----> 1 print(df.columns)
#
# AttributeError: 'str' object has no attribute 'columns'

# %%
df.dtypes
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-5cc0934cc03c> in <module>
# ----> 1 df.dtypes
#
# AttributeError: 'str' object has no attribute 'dtypes'

# %%
df = pd.read_csv('DC_Properties.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-2e15e8e56a98> in <module>
# ----> 1 df = pd.read_csv('DC_Properties.csv')
#
# NameError: name 'pd' is not defined

# %%
import glob

# %%
all_data = pd.DataFrame()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-5419ce91d88f> in <module>
# ----> 1 all_data = pd.DataFrame()
#
# NameError: name 'pd' is not defined

# %%
pd = 'DC_Properties.csv'

# %%
df = pd.read.csv (location)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-ef360c2a3f24> in <module>
# ----> 1 df = pd.read.csv (location)
#
# AttributeError: 'str' object has no attribute 'read'

# %%
df = pd.read.csv ('DC_Properties.csv')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-8e166dd93155> in <module>
# ----> 1 df = pd.read.csv ('DC_Properties.csv')
#
# AttributeError: 'str' object has no attribute 'read'

# %%
df.head
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-89148ddff993> in <module>
# ----> 1 df.head
#
# NameError: name 'df' is not defined

# %%
df.count
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-bb577560d65f> in <module>
# ----> 1 df.count
#
# NameError: name 'df' is not defined

# %%
pd = "DC_Properties.csv"

# %%
df = pd.DataFrame
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-dc3d6633a9e8> in <module>
# ----> 1 df = pd.DataFrame
#
# AttributeError: 'str' object has no attribute 'DataFrame'

# %%
location = "DC_Properties.csv"

# %%
df = pd.read_csv(location)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-b53bd3c9f910> in <module>
# ----> 1 df = pd.read_csv(location)
#
# AttributeError: 'str' object has no attribute 'read_csv'

# %%
import csv

# %%
import pandas as pd

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-c42a15b2c7cf> in <module>
# ----> 1 df.head()
#
# NameError: name 'df' is not defined

# %%
location = "DC_Properties.csv"

# %%
df = pd.read_csv(location)
# Out:
# C:\Users\kenbe\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3020: DtypeWarning: Columns (18,19,20,21,22,23,24,33,34,35,37,43,45) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head
# Out:
# <bound method NDFrame.head of         Unnamed: 0  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  \
# 0                0       4          0      Warm Cool  Y        2.0      8
# 1                1       3          1      Warm Cool  Y        2.0     11
# 2                2       3          1  Hot Water Rad  Y        2.0      9
# 3                3       3          1  Hot Water Rad  Y        2.0      8
# 4                4       2          1      Warm Cool  Y        1.0     11
# 5                5       3          2  Hot Water Rad  Y        1.0     10
# 6                6       1          0      Warm Cool  Y        2.0      5
# 7                7       3          1  Hot Water Rad  Y        2.0      8
# 8                8       3          1      Warm Cool  Y        2.0      7
# 9                9       1          1  Hot Water Rad  Y        1.0      6
# 10              10       3          0     Forced Air  N        3.0     12
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'BATHRM', 'HF_BATHRM', 'HEAT', 'AC', 'NUM_UNITS', 'ROOMS',
#        'BEDRM', 'AYB', 'YR_RMDL', 'EYB', 'STORIES', 'SALEDATE', 'PRICE',
#        'QUALIFIED', 'SALE_NUM', 'GBA', 'BLDG_NUM', 'STYLE', 'STRUCT', 'GRADE',
#        'CNDTN', 'EXTWALL', 'ROOF', 'INTWALL', 'KITCHENS', 'FIREPLACES',
#        'USECODE', 'LANDAREA', 'GIS_LAST_MOD_DTTM', 'SOURCE', 'CMPLX_NUM',
#        'LIVING_GBA', 'FULLADDRESS', 'CITY', 'STATE', 'ZIPCODE', 'NATIONALGRID',
#        'LATITUDE', 'LONGITUDE', 'ASSESSMENT_NBHD', 'ASSESSMENT_SUBNBHD',
#        'CENSUS_TRACT', 'CENSUS_BLOCK', 'WARD', 'SQUARE', 'X', 'Y', 'QUADRANT'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Unnamed: 0              int64
# BATHRM                  int64
# HF_BATHRM               int64
# HEAT                   object
# AC                     object
# NUM_UNITS             float64
# ROOMS                   int64
# BEDRM                   int64
# AYB                   float64
# YR_RMDL               float64
# EYB                     int64
# STORIES               float64
# SALEDATE               object
# PRICE                 float64
# QUALIFIED              object
# SALE_NUM                int64
# GBA                   float64
# BLDG_NUM                int64
# STYLE                  object
# STRUCT                 object
# GRADE                  object
# CNDTN                  object
# EXTWALL                object
# ROOF                   object
# INTWALL                object
# KITCHENS              float64
# FIREPLACES              int64
# USECODE                 int64
# LANDAREA                int64
# GIS_LAST_MOD_DTTM      object
# SOURCE                 object
# ...

# %%
df.count
# Out:
# <bound method DataFrame.count of         Unnamed: 0  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  \
# 0                0       4          0      Warm Cool  Y        2.0      8
# 1                1       3          1      Warm Cool  Y        2.0     11
# 2                2       3          1  Hot Water Rad  Y        2.0      9
# 3                3       3          1  Hot Water Rad  Y        2.0      8
# 4                4       2          1      Warm Cool  Y        1.0     11
# 5                5       3          2  Hot Water Rad  Y        1.0     10
# 6                6       1          0      Warm Cool  Y        2.0      5
# 7                7       3          1  Hot Water Rad  Y        2.0      8
# 8                8       3          1      Warm Cool  Y        2.0      7
# 9                9       1          1  Hot Water Rad  Y        1.0      6
# 10              10       3          0     Forced Air  N        3.0     12
# ...

# %%
df.count
# Out:
# <bound method DataFrame.count of         Unnamed: 0  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  \
# 0                0       4          0      Warm Cool  Y        2.0      8
# 1                1       3          1      Warm Cool  Y        2.0     11
# 2                2       3          1  Hot Water Rad  Y        2.0      9
# 3                3       3          1  Hot Water Rad  Y        2.0      8
# 4                4       2          1      Warm Cool  Y        1.0     11
# 5                5       3          2  Hot Water Rad  Y        1.0     10
# 6                6       1          0      Warm Cool  Y        2.0      5
# 7                7       3          1  Hot Water Rad  Y        2.0      8
# 8                8       3          1      Warm Cool  Y        2.0      7
# 9                9       1          1  Hot Water Rad  Y        1.0      6
# 10              10       3          0     Forced Air  N        3.0     12
# ...

# %%
df['HF_BATHRM']
# Out:
# 0         0
# 1         1
# 2         1
# 3         1
# 4         1
# 5         2
# 6         0
# 7         1
# 8         1
# 9         1
# 10        0
# 11        0
# 12        0
# 13        0
# 14        1
# 15        1
# 16        1
# 17        0
# 18        1
# 19        1
# 20        1
# 21        0
# 22        0
# 23        1
# 24        1
# 25        0
# 26        0
# 27        0
# 28        0
# 29        1
#          ..
# 158927    0
# 158928    1
# 158929    1
# 158930    0
# 158931    1
# 158932    1
# 158933    0
# 158934    1
# 158935    0
# 158936    0
# 158937    0
# 158938    0
# 158939    0
# 158940    0
# 158941    0
# 158942    0
# 158943    1
# 158944    1
# 158945    0
# 158946    0
# 158947    0
# 158948    0
# 158949    1
# 158950    0
# 158951    1
# 158952    0
# 158953    0
# 158954    0
# 158955    0
# 158956    0
# Name: HF_BATHRM, Length: 158957, dtype: int64

# %%
df['HF_BATHRM']
# Out:
# 0         0
# 1         1
# 2         1
# 3         1
# 4         1
# 5         2
# 6         0
# 7         1
# 8         1
# 9         1
# 10        0
# 11        0
# 12        0
# 13        0
# 14        1
# 15        1
# 16        1
# 17        0
# 18        1
# 19        1
# 20        1
# 21        0
# 22        0
# 23        1
# 24        1
# 25        0
# 26        0
# 27        0
# 28        0
# 29        1
#          ..
# 158927    0
# 158928    1
# 158929    1
# 158930    0
# 158931    1
# 158932    1
# 158933    0
# 158934    1
# 158935    0
# 158936    0
# 158937    0
# 158938    0
# 158939    0
# 158940    0
# 158941    0
# 158942    0
# 158943    1
# 158944    1
# 158945    0
# 158946    0
# 158947    0
# 158948    0
# 158949    1
# 158950    0
# 158951    1
# 158952    0
# 158953    0
# 158954    0
# 158955    0
# 158956    0
# Name: HF_BATHRM, Length: 158957, dtype: int64

# %%
data_array.dtype
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-e69879538278> in <module>
# ----> 1 data_array.dtype
#
# NameError: name 'data_array' is not defined

# %%
df.index
# Out:
# RangeIndex(start=0, stop=158957, step=1)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'BATHRM', 'HF_BATHRM', 'HEAT', 'AC', 'NUM_UNITS', 'ROOMS',
#        'BEDRM', 'AYB', 'YR_RMDL', 'EYB', 'STORIES', 'SALEDATE', 'PRICE',
#        'QUALIFIED', 'SALE_NUM', 'GBA', 'BLDG_NUM', 'STYLE', 'STRUCT', 'GRADE',
#        'CNDTN', 'EXTWALL', 'ROOF', 'INTWALL', 'KITCHENS', 'FIREPLACES',
#        'USECODE', 'LANDAREA', 'GIS_LAST_MOD_DTTM', 'SOURCE', 'CMPLX_NUM',
#        'LIVING_GBA', 'FULLADDRESS', 'CITY', 'STATE', 'ZIPCODE', 'NATIONALGRID',
#        'LATITUDE', 'LONGITUDE', 'ASSESSMENT_NBHD', 'ASSESSMENT_SUBNBHD',
#        'CENSUS_TRACT', 'CENSUS_BLOCK', 'WARD', 'SQUARE', 'X', 'Y', 'QUADRANT'],
#       dtype='object')

# %%
mean('HF_BATHRM')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-c541f4ae23fa> in <module>
# ----> 1 mean('HF_BATHRM')
#
# NameError: name 'mean' is not defined

# %%
mean['HF_BATHRM']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-72aa020f3f0e> in <module>
# ----> 1 mean['HF_BATHRM']
#
# NameError: name 'mean' is not defined

# %%
df[BEDRM]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-4854944390f7> in <module>
# ----> 1 df[BEDRM]
#
# NameError: name 'BEDRM' is not defined

# %%
df.head
# Out:
# <bound method NDFrame.head of         Unnamed: 0  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  \
# 0                0       4          0      Warm Cool  Y        2.0      8
# 1                1       3          1      Warm Cool  Y        2.0     11
# 2                2       3          1  Hot Water Rad  Y        2.0      9
# 3                3       3          1  Hot Water Rad  Y        2.0      8
# 4                4       2          1      Warm Cool  Y        1.0     11
# 5                5       3          2  Hot Water Rad  Y        1.0     10
# 6                6       1          0      Warm Cool  Y        2.0      5
# 7                7       3          1  Hot Water Rad  Y        2.0      8
# 8                8       3          1      Warm Cool  Y        2.0      7
# 9                9       1          1  Hot Water Rad  Y        1.0      6
# 10              10       3          0     Forced Air  N        3.0     12
# ...

# %%
df(LONGITUDE)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-3458b96d5ecd> in <module>
# ----> 1 df(LONGITUDE)
#
# NameError: name 'LONGITUDE' is not defined

# %%
df(Unnamed)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-41d7aae6dde0> in <module>
# ----> 1 df(Unnamed)
#
# NameError: name 'Unnamed' is not defined

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'BATHRM', 'HF_BATHRM', 'HEAT', 'AC', 'NUM_UNITS', 'ROOMS',
#        'BEDRM', 'AYB', 'YR_RMDL', 'EYB', 'STORIES', 'SALEDATE', 'PRICE',
#        'QUALIFIED', 'SALE_NUM', 'GBA', 'BLDG_NUM', 'STYLE', 'STRUCT', 'GRADE',
#        'CNDTN', 'EXTWALL', 'ROOF', 'INTWALL', 'KITCHENS', 'FIREPLACES',
#        'USECODE', 'LANDAREA', 'GIS_LAST_MOD_DTTM', 'SOURCE', 'CMPLX_NUM',
#        'LIVING_GBA', 'FULLADDRESS', 'CITY', 'STATE', 'ZIPCODE', 'NATIONALGRID',
#        'LATITUDE', 'LONGITUDE', 'ASSESSMENT_NBHD', 'ASSESSMENT_SUBNBHD',
#        'CENSUS_TRACT', 'CENSUS_BLOCK', 'WARD', 'SQUARE', 'X', 'Y', 'QUADRANT'],
#       dtype='object')

# %%
df.head
# Out:
# <bound method NDFrame.head of         Unnamed: 0  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  \
# 0                0       4          0      Warm Cool  Y        2.0      8
# 1                1       3          1      Warm Cool  Y        2.0     11
# 2                2       3          1  Hot Water Rad  Y        2.0      9
# 3                3       3          1  Hot Water Rad  Y        2.0      8
# 4                4       2          1      Warm Cool  Y        1.0     11
# 5                5       3          2  Hot Water Rad  Y        1.0     10
# 6                6       1          0      Warm Cool  Y        2.0      5
# 7                7       3          1  Hot Water Rad  Y        2.0      8
# 8                8       3          1      Warm Cool  Y        2.0      7
# 9                9       1          1  Hot Water Rad  Y        1.0      6
# 10              10       3          0     Forced Air  N        3.0     12
# ...

# %%
df(HF_BATHRM).max()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-34789448209b> in <module>
# ----> 1 df(HF_BATHRM).max()
#
# NameError: name 'HF_BATHRM' is not defined

# %%
df('HF_BATHRM').max()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-eb1c2f03a572> in <module>
# ----> 1 df('HF_BATHRM').max()
#
# TypeError: 'DataFrame' object is not callable

# %%
df.count
# Out:
# <bound method DataFrame.count of         Unnamed: 0  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  \
# 0                0       4          0      Warm Cool  Y        2.0      8
# 1                1       3          1      Warm Cool  Y        2.0     11
# 2                2       3          1  Hot Water Rad  Y        2.0      9
# 3                3       3          1  Hot Water Rad  Y        2.0      8
# 4                4       2          1      Warm Cool  Y        1.0     11
# 5                5       3          2  Hot Water Rad  Y        1.0     10
# 6                6       1          0      Warm Cool  Y        2.0      5
# 7                7       3          1  Hot Water Rad  Y        2.0      8
# 8                8       3          1      Warm Cool  Y        2.0      7
# 9                9       1          1  Hot Water Rad  Y        1.0      6
# 10              10       3          0     Forced Air  N        3.0     12
# ...

# %%
df['DC_Properties.csv'].max()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'DC_Properties.csv'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-35-72dc89876090> in <module>
# ----> 1 df['DC_Properties.csv'].max()
#
# ...

# %%
df['BEDRM'].max()
# Out:
# 24

# %%
df['BEDRM'].min()
# Out:
# 0

# %%
df['BEDRM'].min()
# Out:
# 0

# %%
df['BEDRM'].sum()
# Out:
# 434351

# %%
df['BEDRM'].mean()
# Out:
# 2.7325062752819944

# %%
df['BEDRM'].median()
# Out:
# 3.0

# %%
df['BEDRM'].mode()
# Out:
# 0    3
# dtype: int64

# %%
df['BEDRM'].value_counts()
# Out:
# 3     57864
# 2     34946
# 4     24893
# 1     24181
# 5      6898
# 0      5297
# 6      3090
# 8       792
# 7       750
# 9       123
# 10       62
# 12       34
# 11       13
# 13        4
# 15        3
# 14        2
# 16        2
# 20        1
# 19        1
# 24        1
# Name: BEDRM, dtype: int64

# %%
df['BEDRM'].std()
# Out:
# 1.3588642440202134

# %%
 df['ASSESSMENT_SUBNBHD'].max() df['BEDRM'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\nanops.py in f(values, axis, skipna, **kwds)
#     127                 else:
# --> 128                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     129             except Exception:
#
# ~\Anaconda3\lib\site-packages\pandas\core\nanops.py in reduction(values, axis, skipna)
#     506         else:
# --> 507             result = getattr(values, meth)(axis)
#     508
#
# ~\Anaconda3\lib\site-packages\numpy\core\_methods.py in _amax(a, axis, out, keepdims, initial)
#      27           initial=_NoValue):
# ---> 28     return umr_maximum(a, axis, None, out, keepdims, initial)
#      29
#
# TypeError: '>=' not supported between instances of 'str' and 'float'
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
 df['ASSESSMENT_SUBNBHD'].value_counts()
# Out:
# 040 D Old City 2             4403
# 040 E Old City 2             2968
# 040 C Old City 2             2886
# 042 B Petworth               2763
# 039 K Old City 1             2640
# 007 E Brookland              2388
# 040 B Old City 2             2289
# 015 D Columbia Heights       2246
# 015 A Columbia Heights       2206
# 015 E Columbia Heights       2183
# 016 B Congress Heights       2120
# 042 C Petworth               2017
# 039 L Old City 1             1908
# 028 C Hillcrest              1881
# 011 A Chevy Chase            1823
# 018 C Deanwood               1783
# 036 A Mt. Pleasant           1762
# 039 F Old City 1             1717
# 016 C Congress Heights       1633
# 007 C Brookland              1631
# 018 B Deanwood               1613
# 054 B Wesley Heights         1570
# 015 C Columbia Heights       1561
# 018 A Deanwood               1552
# 033 A Marshall Heights       1549
# 042 A Petworth               1543
# 039 A Old City 1             1538
# ...

# %%
 df['ASSESSMENT_SUBNBHD'].mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\nanops.py in f(values, axis, skipna, **kwds)
#     127                 else:
# --> 128                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     129             except Exception:
#
# ~\Anaconda3\lib\site-packages\pandas\core\nanops.py in nanmean(values, axis, skipna)
#     354     count = _get_counts(mask, axis, dtype=dtype_count)
# --> 355     the_sum = _ensure_numeric(values.sum(axis, dtype=dtype_sum))
#     356
#
# ~\Anaconda3\lib\site-packages\numpy\core\_methods.py in _sum(a, axis, dtype, out, keepdims, initial)
#      35          initial=_NoValue):
# ---> 36     return umr_sum(a, axis, dtype, out, keepdims, initial)
#      37
#
# TypeError: can only concatenate str (not "int") to str
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
 df.describe['ASSESSMENT_SUBNBHD']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-49-080b0e262ca1> in <module>
# ----> 1 df.describe['ASSESSMENT_SUBNBHD']
#
# TypeError: 'method' object is not subscriptable

# %%
df['AYB'],max()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-50-fe406d258888> in <module>
# ----> 1 df['AYB'],max()
#
# TypeError: max expected 1 arguments, got 0

# %%
df['AYB'].max()
# Out:
# 2019.0

# %%
df['AYB'].min()
# Out:
# 1754.0

# %%
df['AYB'].sum()
# Out:
# 308166241.0

# %%
df['AYB'].median()
# Out:
# 1937.0

# %%
df['AYB'].mode()
# Out:
# 0    1900.0
# dtype: float64

# %%
df['AYB'].value_counts()
# Out:
# 1900.0    8967
# 1925.0    5129
# 1910.0    4563
# 1940.0    4316
# 1923.0    3724
# 1927.0    3707
# 1941.0    3420
# 1926.0    3117
# 1942.0    3058
# 1939.0    2849
# 1950.0    2696
# 1937.0    2690
# 1936.0    2553
# 2007.0    2291
# 1908.0    2274
# 1912.0    2272
# 1938.0    2246
# 1928.0    2190
# 1909.0    2154
# 2005.0    2146
# 1951.0    2086
# 1947.0    2058
# 1920.0    2019
# 2006.0    2019
# 1890.0    1976
# 1930.0    1884
# 1929.0    1838
# 1960.0    1816
# 1948.0    1808
# 1911.0    1807
#           ...
# 1819.0       2
# 1835.0       2
# 1861.0       2
# 1847.0       2
# 1849.0       2
# 1824.0       2
# 1808.0       1
# 1793.0       1
# 1765.0       1
# 1866.0       1
# 1782.0       1
# 1784.0       1
# 1785.0       1
# 1787.0       1
# 1788.0       1
# 1854.0       1
# 1791.0       1
# 1851.0       1
# 1834.0       1
# 1795.0       1
# 1822.0       1
# 1797.0       1
# 1799.0       1
# 1833.0       1
# 1846.0       1
# 1844.0       1
# 1842.0       1
# ...

# %%
df['AYB'].std()
# Out:
# 33.64023357603095

# %%
df.groupby(['AYB', 'ASSESSMENT_SUBNBHD'])

# %%
df.groupby(['AYB', 'ASSESSMENT_SUBNBHD','Grade'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-60-74c2e49f7d36> in <module>
# ----> 1 df.groupby(['AYB', 'ASSESSMENT_SUBNBHD','Grade'])
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, **kwargs)
#    6663         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
#    6664                        sort=sort, group_keys=group_keys, squeeze=squeeze,
# -> 6665                        observed=observed, **kwargs)
#    6666
#    6667     def asfreq(self, freq, method=None, how=None, normalize=False,
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in groupby(obj, by, **kwds)
#    2150         raise TypeError('invalid type: %s' % type(obj))
#    2151
# -> 2152     return klass(obj, by, **kwds)
#    2153
#    2154
#
# ...

# %%
df.groupby(['AYB', 'ASSESSMENT_SUBNBHD','GRADE'])

# %%
df.groupby(['AYB', 'ASSESSMENT_SUBNBHD','GRADE','QUADRANT','PRICE',])

# %%
df.dtypes
# Out:
# Unnamed: 0              int64
# BATHRM                  int64
# HF_BATHRM               int64
# HEAT                   object
# AC                     object
# NUM_UNITS             float64
# ROOMS                   int64
# BEDRM                   int64
# AYB                   float64
# YR_RMDL               float64
# EYB                     int64
# STORIES               float64
# SALEDATE               object
# PRICE                 float64
# QUALIFIED              object
# SALE_NUM                int64
# GBA                   float64
# BLDG_NUM                int64
# STYLE                  object
# STRUCT                 object
# GRADE                  object
# CNDTN                  object
# EXTWALL                object
# ROOF                   object
# INTWALL                object
# KITCHENS              float64
# FIREPLACES              int64
# USECODE                 int64
# LANDAREA                int64
# GIS_LAST_MOD_DTTM      object
# SOURCE                 object
# ...

# %%
pd.pivot_table
# Out:
# <function pandas.core.reshape.pivot.pivot_table(data, values=None, index=None, columns=None, aggfunc='mean', fill_value=None, margins=False, dropna=True, margins_name='All')>

# %%
pd.pivot_table(df, values=['AYB'],index=['ASSESSMENT_SUBNBHD'] )
# Out:
#                                    AYB
# ASSESSMENT_SUBNBHD
# 001 A American University  1934.508728
# 001 B American University  1946.913970
# 001 C American University  1941.039088
# 002 A Anacostia            1940.461340
# 002 B Anacostia            1939.491259
# 004 A Berkley              1947.068702
# 004 B Berkley              1966.912281
# 004 C Berkley              1979.993464
# 005 A Brentwood            1945.671296
# 005 B Brentwood            1949.223404
# 006 A Brightwood           1940.913943
# 006 B Brightwood           1942.359638
# 006 C Brightwood           1928.957553
# 006 D Brightwood           1937.896296
# 006 E Brightwood           1931.688119
# 007 A Brookland            1945.826490
# 007 B Brookland            1958.501250
# 007 C Brookland            1942.086154
# 007 D Brookland            1927.801199
# 007 E Brookland            1945.643678
# 008 A Burleith             1925.500000
# 008 B Burleith             1987.329588
# ...

# %%
pd.pivot_table(df, values=['AYB'], index=['PRICE'])
# Out:
#                      AYB
# PRICE
# 1.0          1953.000000
# 10.0         1917.750000
# 250.0        1914.428571
# 500.0        1908.333333
# 936.0        1900.000000
# 1000.0       1935.800000
# 1377.0       1900.000000
# 2000.0       1914.000000
# 3000.0       1999.500000
# 3270.0       1950.000000
# 3523.0       1949.000000
# 3997.0       1948.000000
# 4101.0       1945.000000
# 4156.0       1937.000000
# 4500.0       1907.000000
# 4850.0       1998.666667
# 5000.0       1927.750000
# 5115.0       2005.000000
# 5185.0       2014.000000
# 5247.0       1908.000000
# 5400.0       1918.000000
# 5453.0       1964.000000
# 5522.0       1940.000000
# 5643.0       2008.000000
# 5964.0       1927.000000
# 6000.0       1931.500000
# 6826.0       1965.000000
# 6950.0       1875.000000
# 7000.0       2002.000000
# 7425.0       1953.000000
# ...                  ...
# 7950000.0    1929.000000
# 8000000.0    2003.000000
# 8100000.0    1928.000000
# 8243685.0    1989.000000
# ...

# %%
pd.pivot_table(df.groupby(['AYB','PRICE'])values=['AYB'])
# Out:
#   File "<ipython-input-73-7a169c4ed118>", line 1
#     pd.pivot_table(df.groupby(['AYB','PRICE'])values=['AYB'])
#                                                    ^
# SyntaxError: invalid syntax

# %%
 df['ASSESSMENT_SUBNBHD'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c9a887a19a5a> in <module>
# ----> 1 df['ASSESSMENT_SUBNBHD'].value_counts()
#
# NameError: name 'df' is not defined

# %%
pd.pivot_table(df, values=['ASSESSMENT_SUBNBHD'], index=['PRICE'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-be82dd7ada46> in <module>
# ----> 1 pd.pivot_table(df, values=['ASSESSMENT_SUBNBHD'], index=['PRICE'])
#
# NameError: name 'pd' is not defined

# %%
location = "DC_Properties.csv"
df = pd.read_csv(location)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-d6599ead9590> in <module>
#       1 location = "DC_Properties.csv"
# ----> 2 df = pd.read_csv(location)
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd

# %%
import csv

# %%
location = "DC_Properties.csv"

# %%
df = pd.read_csv(location)
# Out:
# C:\Users\kenbe\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3020: DtypeWarning: Columns (18,19,20,21,22,23,24,33,34,35,37,43,45) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
import csv

# %%
df.head()
# Out:
#    Unnamed: 0  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  BEDRM  \
# 0           0       4          0      Warm Cool  Y        2.0      8      4
# 1           1       3          1      Warm Cool  Y        2.0     11      5
# 2           2       3          1  Hot Water Rad  Y        2.0      9      5
# 3           3       3          1  Hot Water Rad  Y        2.0      8      5
# 4           4       2          1      Warm Cool  Y        1.0     11      3
#
#       AYB  YR_RMDL   ...     LONGITUDE  ASSESSMENT_NBHD ASSESSMENT_SUBNBHD  \
# 0  1910.0   1988.0   ...    -77.040832       Old City 2   040 D Old City 2
# 1  1898.0   2007.0   ...    -77.040764       Old City 2   040 D Old City 2
# 2  1910.0   2009.0   ...    -77.040678       Old City 2   040 D Old City 2
# 3  1900.0   2003.0   ...    -77.040629       Old City 2   040 D Old City 2
# 4  1913.0   2012.0   ...    -77.039361       Old City 2   040 D Old City 2
#
# ...

# %%
pd.pivot_table(df, values=['ASSESSMENT_SUBNBHD'], index=['PRICE'])
# Out:
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# <ipython-input-15-be82dd7ada46> in <module>
# ----> 1 pd.pivot_table(df, values=['ASSESSMENT_SUBNBHD'], index=['PRICE'])
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\pivot.py in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name)
#      85     # if we have a categorical
#      86     grouped = data.groupby(keys, observed=False)
# ---> 87     agged = grouped.agg(aggfunc)
#      88     if dropna and isinstance(agged, ABCDataFrame) and len(agged.columns):
#      89         agged = agged.dropna(how='all')
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in aggregate(self, arg, *args, **kwargs)
#    4654         axis=''))
#    4655     def aggregate(self, arg, *args, **kwargs):
# -> 4656         return super(DataFrameGroupBy, self).aggregate(arg, *args, **kwargs)
# ...

# %%
pd.pivot_table(df, values=['AYB'], index=['PRICE'])
# Out:
#                      AYB
# PRICE
# 1.0          1953.000000
# 10.0         1917.750000
# 250.0        1914.428571
# 500.0        1908.333333
# 936.0        1900.000000
# 1000.0       1935.800000
# 1377.0       1900.000000
# 2000.0       1914.000000
# 3000.0       1999.500000
# 3270.0       1950.000000
# 3523.0       1949.000000
# 3997.0       1948.000000
# 4101.0       1945.000000
# 4156.0       1937.000000
# 4500.0       1907.000000
# 4850.0       1998.666667
# 5000.0       1927.750000
# 5115.0       2005.000000
# 5185.0       2014.000000
# 5247.0       1908.000000
# 5400.0       1918.000000
# 5453.0       1964.000000
# 5522.0       1940.000000
# 5643.0       2008.000000
# 5964.0       1927.000000
# 6000.0       1931.500000
# 6826.0       1965.000000
# 6950.0       1875.000000
# 7000.0       2002.000000
# 7425.0       1953.000000
# ...                  ...
# 7950000.0    1929.000000
# 8000000.0    2003.000000
# 8100000.0    1928.000000
# 8243685.0    1989.000000
# ...

# %%
pd.pivot_table(df, values=['ASSESSMENT_SUBNBHD'], index=['PRICE'])
# Out:
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# <ipython-input-17-be82dd7ada46> in <module>
# ----> 1 pd.pivot_table(df, values=['ASSESSMENT_SUBNBHD'], index=['PRICE'])
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\pivot.py in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name)
#      85     # if we have a categorical
#      86     grouped = data.groupby(keys, observed=False)
# ---> 87     agged = grouped.agg(aggfunc)
#      88     if dropna and isinstance(agged, ABCDataFrame) and len(agged.columns):
#      89         agged = agged.dropna(how='all')
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in aggregate(self, arg, *args, **kwargs)
#    4654         axis=''))
#    4655     def aggregate(self, arg, *args, **kwargs):
# -> 4656         return super(DataFrameGroupBy, self).aggregate(arg, *args, **kwargs)
# ...

# %%
pd.pivot_table(df, values=['WARD'], index=['PRICE'])
# Out:
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# <ipython-input-18-181f7784325e> in <module>
# ----> 1 pd.pivot_table(df, values=['WARD'], index=['PRICE'])
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\pivot.py in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name)
#      85     # if we have a categorical
#      86     grouped = data.groupby(keys, observed=False)
# ---> 87     agged = grouped.agg(aggfunc)
#      88     if dropna and isinstance(agged, ABCDataFrame) and len(agged.columns):
#      89         agged = agged.dropna(how='all')
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in aggregate(self, arg, *args, **kwargs)
#    4654         axis=''))
#    4655     def aggregate(self, arg, *args, **kwargs):
# -> 4656         return super(DataFrameGroupBy, self).aggregate(arg, *args, **kwargs)
#    4657
# ...

# %%
pd.pivot_table(df, values=['AYB'], index=['WARD'])
# Out:
#                 AYB
# WARD
# Ward 1  1932.394815
# Ward 2  1948.277683
# Ward 3  1947.718658
# Ward 4  1934.738544
# Ward 5  1938.522708
# Ward 6  1933.772784
# Ward 7  1950.822649
# Ward 8  1957.728817

# %%
pd.pivot_table(df, values=['PRICE'], index=['WARD'])
# Out:
#                PRICE
# WARD
# Ward 1  5.738363e+05
# Ward 2  1.098570e+06
# Ward 3  3.077716e+06
# Ward 4  4.899224e+05
# Ward 5  3.952432e+05
# Ward 6  5.268684e+05
# Ward 7  2.339222e+05
# Ward 8  2.715224e+05

# %%
pd.pivot_table(df, values=['WARD'], index=['PRICE'])
# Out:
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# <ipython-input-21-181f7784325e> in <module>
# ----> 1 pd.pivot_table(df, values=['WARD'], index=['PRICE'])
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\pivot.py in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name)
#      85     # if we have a categorical
#      86     grouped = data.groupby(keys, observed=False)
# ---> 87     agged = grouped.agg(aggfunc)
#      88     if dropna and isinstance(agged, ABCDataFrame) and len(agged.columns):
#      89         agged = agged.dropna(how='all')
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in aggregate(self, arg, *args, **kwargs)
#    4654         axis=''))
#    4655     def aggregate(self, arg, *args, **kwargs):
# -> 4656         return super(DataFrameGroupBy, self).aggregate(arg, *args, **kwargs)
#    4657
# ...

# %%
df['WARD'].value_counts()
# Out:
# Ward 6    23973
# Ward 3    23688
# Ward 4    22202
# Ward 2    22167
# Ward 5    21359
# Ward 1    17455
# Ward 7    17206
# Ward 8    10906
# Name: WARD, dtype: int64

# %%
df.count
# Out:
# <bound method DataFrame.count of         Unnamed: 0  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  \
# 0                0       4          0      Warm Cool  Y        2.0      8
# 1                1       3          1      Warm Cool  Y        2.0     11
# 2                2       3          1  Hot Water Rad  Y        2.0      9
# 3                3       3          1  Hot Water Rad  Y        2.0      8
# 4                4       2          1      Warm Cool  Y        1.0     11
# 5                5       3          2  Hot Water Rad  Y        1.0     10
# 6                6       1          0      Warm Cool  Y        2.0      5
# 7                7       3          1  Hot Water Rad  Y        2.0      8
# 8                8       3          1      Warm Cool  Y        2.0      7
# 9                9       1          1  Hot Water Rad  Y        1.0      6
# 10              10       3          0     Forced Air  N        3.0     12
# ...

# %%
df['Unamed'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Unamed'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-de68126dd6f2> in <module>
# ----> 1 df['Unamed'].value_counts()
#
# ...

# %%
df['Unnamed'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Unnamed'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-25-3b47eaacde1a> in <module>
# ----> 1 df['Unnamed'].value_counts()
#
# ...

# %%
WARD = ['Ward 6', 'Ward 8']
QUADRANT = ['NW', 'SW']
df
# Out:
#         Unnamed: 0  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  \
# 0                0       4          0      Warm Cool  Y        2.0      8
# 1                1       3          1      Warm Cool  Y        2.0     11
# 2                2       3          1  Hot Water Rad  Y        2.0      9
# 3                3       3          1  Hot Water Rad  Y        2.0      8
# 4                4       2          1      Warm Cool  Y        1.0     11
# 5                5       3          2  Hot Water Rad  Y        1.0     10
# 6                6       1          0      Warm Cool  Y        2.0      5
# 7                7       3          1  Hot Water Rad  Y        2.0      8
# 8                8       3          1      Warm Cool  Y        2.0      7
# 9                9       1          1  Hot Water Rad  Y        1.0      6
# 10              10       3          0     Forced Air  N        3.0     12
# 11              11       5          0  Hot Water Rad  Y        3.0     16
# ...

# %%
df.head
# Out:
# <bound method NDFrame.head of         Unnamed: 0  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  \
# 0                0       4          0      Warm Cool  Y        2.0      8
# 1                1       3          1      Warm Cool  Y        2.0     11
# 2                2       3          1  Hot Water Rad  Y        2.0      9
# 3                3       3          1  Hot Water Rad  Y        2.0      8
# 4                4       2          1      Warm Cool  Y        1.0     11
# 5                5       3          2  Hot Water Rad  Y        1.0     10
# 6                6       1          0      Warm Cool  Y        2.0      5
# 7                7       3          1  Hot Water Rad  Y        2.0      8
# 8                8       3          1      Warm Cool  Y        2.0      7
# 9                9       1          1  Hot Water Rad  Y        1.0      6
# 10              10       3          0     Forced Air  N        3.0     12
# ...

# %%
WARD = ['Ward 6', 'Ward 8']
QUADRANT = ['NW', 'SW']
col = ['Ward 6', 'Ward 8']
Degrees = ['NW', 'SW']

# %%
df = pd.DataFrame (data=WARD, columns=QUADRANT)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\internals.py in create_block_manager_from_blocks(blocks, axes)
#    4856                 blocks = [make_block(values=blocks[0],
# -> 4857                                      placement=slice(0, len(axes[0])))]
#    4858
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals.py in make_block(values, placement, klass, ndim, dtype, fastpath)
#    3204
# -> 3205     return klass(values, ndim=ndim, placement=placement)
#    3206
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals.py in __init__(self, values, placement, ndim)
#    2302         super(ObjectBlock, self).__init__(values, ndim=ndim,
# -> 2303                                           placement=placement)
#    2304
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals.py in __init__(self, values, placement, ndim)
# ...

# %%
df = pd.DataFrame

# %%
#I was trying to show that the wards were differen based on price and other criteria for this project.

# %%
 df['WARD'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-e7af96d271aa> in <module>
# ----> 1 df['WARD'].value_counts()
#
# TypeError: 'type' object is not subscriptable
